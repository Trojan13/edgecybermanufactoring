# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import time

# %%
time_data = pd.read_csv("data.csv")
time_data= time_data.multiply(1000)
time_data= time_data.round()
time_data
# Out:
#     Ping Time Edge  Ping Time Cloud  Task Time Edge  Task Time Cloud
# 0            181.0            213.0           297.0            127.0
# 1            214.0             17.0           211.0             42.0
# 2            232.0             33.0           231.0             58.0
# 3            243.0             55.0           220.0             68.0
# 4            258.0             60.0           273.0             90.0
# ..             ...              ...             ...              ...
# 95           218.0             19.0           227.0             35.0
# 96           235.0             13.0           203.0             70.0
# 97           189.0             57.0           370.0            196.0
# 98           263.0             14.0           123.0             45.0
# 99           381.0            188.0           172.0             35.0
#
# [100 rows x 4 columns]

# %%
from cProfile import label


time_data_descr = time_data.describe()
print(time_data_descr)
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
barlist=ax.bar(time_data_descr.loc["mean"].index, time_data_descr.loc["mean"],
       yerr=time_data_descr.loc["std"], align='center', alpha=0.5, ecolor='black', capsize=10)
barlist[0].set_color('black')
barlist[1].set_color('gray')
barlist[2].set_color('silver')
barlist[3].set_color("gainsboro")
ax.set_ylabel('Mean time (ms)')
ax.legend(loc='best')
plt.show()
plt.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#        Ping Time Edge  Ping Time Cloud  Task Time Edge  Task Time Cloud
# count      100.000000       100.000000      100.000000       100.000000
# mean       253.140000        84.540000      243.840000       102.320000
# std         71.016148        63.059603       63.648771        64.075221
# min         64.000000        11.000000      123.000000        33.000000
# 25%        204.000000        24.500000      198.250000        49.750000
# 50%        246.500000        70.000000      236.000000        87.500000
# 75%        298.000000       128.000000      275.250000       128.000000
# max        408.000000       231.000000      449.000000       347.000000

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
fig1=ax.plot(time_data["Ping Time Edge"].index,time_data["Ping Time Edge"],time_data["Ping Time Cloud"].index,time_data["Ping Time Cloud"])
fig1[0].set_label("Edge")
fig1[1].set_label("Cloud")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('# Testrun')
ax.set_title('Ping Times')
ax.legend(loc='best')
plt.show()
plt.close()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
fig1=ax.plot(time_data["Task Time Edge"].index,time_data["Task Time Edge"],time_data["Task Time Cloud"].index,time_data["Ping Time Cloud"])
fig1[0].set_label("Edge")
fig1[1].set_label("Cloud")
ax.set_ylabel('Time (ms)')
ax.set_xlabel('# Testrun')
ax.set_title('Task Times')
ax.legend(loc='best')
plt.show()
plt.close()
